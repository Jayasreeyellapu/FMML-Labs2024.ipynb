# %% [markdown]
# <a href="https://colab.research.google.com/github/Jayasreeyellapu/FMML-Labs2024.ipynb/blob/main/Module_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-21 04:11:44--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   132MB/s    in 0.5s
#
# 2025-03-21 04:11:47 (132 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 25438  1509.01329v2  Common visual recognition tasks such as classi...    cs
# 23541   1304.6759v1  In this paper, we propose a new algorithm to m...    cs
# 38348  1610.09516v1  Most street gang members use Twitter to intimi...    cs
# 7682   1802.08012v1  Topic models are one of the most frequently us...  stat
# 1538    1401.5390v1  Domain knowledge is crucial for effective perf...    cs
# ...             ...                                                ...   ...
# 31050  1802.02210v1  Quantitative modeling of human brain activity ...    cs
# 39388  1602.01608v2  In this work, we present an appearance based h...    cs
# 2596   1608.05921v2  Knowledge graph construction consists of two t...  stat
# 10873  1503.03701v4  The counting grid is a grid of microtopics, sp...  stat
# 23290   1012.5933v1  We introduce an (equi-)affine invariant diffus...    cs
#
#                                                    title  year  \
# 25438                       Semantic Amodal Segmentation  2015
# 23541          k-Modulus Method for Image Transformation  2013
# 38348             Finding Street Gang Members on Twitter  2016
# 7682   Learning Topic Models by Neighborhood Aggregation  2018
# 1538   Learning to Win by Reading Manuals in a Monte-...  2014
# ...                                                  ...   ...
# 31050  Describing Semantic Representations of Brain A...  2018
# 39388  Appearance Based Robot and Human Activity Reco...  2016
# 2596   Probabilistic Knowledge Graph Construction: Co...  2016
# 10873      Hierarchical learning of grids of microtopics  2015
# 23290  Affine-invariant diffusion geometry for the an...  2010
#
#                                                 keywords
# 25438  [recognition, classification, detection, segme...
# 23541  [algorithm, transformation, technique, transfo...
# 38348  [intimidate, outrageous, statements, activitie...
# 7682   [frequently, interpretability, structure, exte...
# 1538   [knowledge, effective, performance, autonomous...
# ...                                                  ...
# 31050  [quantitative, representations, neuroscience, ...
# 39388  [appearance, recognition, background, foregrou...
# 2596   [knowledge, construction, extracting, informat...
# 10873  [microtopics, wordfeature, distributions, gene...
# 23290  [introduce, invariant, diffusion, transformati...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 25438    [recognition, classification, detection, segme...
# 23541    [algorithm, transformation, technique, transfo...
# 38348    [intimidate, outrageous, statements, activitie...
# 7682     [frequently, interpretability, structure, exte...
# 1538     [knowledge, effective, performance, autonomous...
#                                ...
# 22289    [information, theoretic, framework, optimizati...
# 39962    [introduce, framework, demonstrate, advantages...
# 14275    [structure, dimensional, graphical, considerab...
# 15555    [bilingual, direction, translation, accurately...
# 10707    [regularized, minimization, dimensional, appli...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8831 words.
# Out of those 4597 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b099ba66-1f18-4e4f-bb0c-6159e512cca5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b099ba66-1f18-4e4f-bb0c-6159e512cca5")) {                    Plotly.newPlot(                        "b099ba66-1f18-4e4f-bb0c-6159e512cca5",                        [{"x":["recognition","performance","annotators","baselines","classification","specifically","algorithmic","conjecture","introduce","reasoning","consistent","techniques","challenges","annotation","including","surprisingly","annotations","information","community","segmentation","statistics","structure","unreasonable","detection","especially","processing","guarantee","algorithm","compression","according","technique","facilitate","multiples","redundancy","predefined","transform","transformation","criterion","differences","challenging","classifier","represent","activities","verifiable","automatically","establishes","classifiers","anticipate","population","statements","supervised","promising","incorporate","nonlinear","aggregation","inference","describing","implementation","occurring","dirichlet","experiments","neighborhood","prediction","corresponds","coherence","intricate","supervisory","interpretability","procedure","embedding","relationship","correspond","extending","frequently","performing","allocation","approximate","outperforms","strategies","improvement","variables","simulated","representing","linguistic","knowledge","counterpart","effective","significantly","effectively","predicate","linguistically","grounding","framework","application","extracted","operating","typically","selection","autonomous","decisions","interprets","parameters","generated","construction","interesting","parallels","directions","equivalence","introduced","relations","summarises","asymptotic","investigation","dependent","structuring","combining","morphological","computing","filtering","equations","structures","particularly","extensions","confirmed","differential","inferences","conditioning","intractable","traditionally","properties","simulations","conditional","likelihood","distribution","preliminary","computation","statistical","posterior","simulation","parametric","representation","estimation","likelihoods","predictions","algorithms","critically","probability","unlabeled","adversarial","leverages","experimental","predicted","demonstrate","trustworthy","discriminator","cityscapes","differentiate","discriminators","providing","convolutional","additional","consideration","resolution","discovering","effectiveness","advantage","reinforcement","currently","introduction","optimisation","represents","previously","asynchronous","advantages","understanding","highlight","expensive","dominated","repetitive","locations","auxiliary","increases","curriculum","difficulty","spatiotemporal","incorrect","similarities","placement","qualitative","ambiguous","gradually","inconsistencies","presently","extensive","quantitative","retrieval","characteristics","embeddings","individual","representations"],"y":[397,929,10,62,534,174,51,9,346,116,81,401,113,65,265,38,65,736,62,200,55,323,3,357,116,291,38,873,47,109,270,44,3,24,21,74,60,43,48,286,154,123,42,1,185,8,108,5,45,16,181,110,61,69,23,191,34,147,17,19,559,22,224,25,13,3,3,16,111,113,75,26,27,39,78,22,92,273,79,150,123,55,78,65,349,15,263,277,102,10,5,8,572,273,121,32,122,159,57,50,1,256,179,82,76,5,30,25,129,94,3,22,32,66,8,111,27,142,61,25,146,81,36,9,26,15,19,29,14,198,43,102,59,207,48,130,176,36,79,40,364,193,3,83,634,8,161,37,102,28,396,39,560,4,18,6,8,5,90,398,109,34,131,20,222,82,98,55,32,23,45,106,10,81,154,34,69,9,5,33,26,55,7,38,12,12,27,8,59,22,18,6,4,194,79,116,82,77,118,228],"type":"bar"},{"x":["recognition","performance","annotators","baselines","classificati ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4597,), (4597, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7841666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimizing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Differentiable</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333334);'>Relaxations</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Coreference</span> <span style='background-color:rgba(0, 255, 0, 0.4200542005420054);'>Evaluation</span> <span style=''>Metrics</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 1.0);'>Coreference</span> <span style='background-color:rgba(0, 255, 0, 0.4200542005420054);'>evaluation</span> <span style=''>metrics</span> <span style=''>are</span> <span style=''>hard</span> <span style=''>to</span> <span style=''>optimize</span> <span style=''>directly</span> <span style=''>as</span> <span style=''>they</span> <span style=''>are</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>differentiable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>not</span> <span style=''>easily</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decomposable</span> <span style=''>into</span> <span style='background-color:rgba(0, 255, 0, 0.625);'>elementary</span> <span style='background-color:rgba(0, 255, 0, 0.36986301369863006);'>decisions</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Consequently</span> <span style=''>most</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>optimize</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objectives</span> <span style=''>only</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>indirectly</span> <span style=''>related</span> <span style=''>to</span> <span style=''>the</span> <span style=''>end</span> <span style=''>goal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resulting</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>suboptimal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>Instead</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>differentiable</span> <span style='background-color:rgba(255, 0, 0, 0.31147540983606564);'>relaxation</span> <span style=''>that</span> <span style=''>lends</span> <span style=''>itself</span> <span style=''>to</span> <span style=''>gradient</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimisation</span> <span style=''>thus</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333334);'>bypassing</span> <span style=''>the</span> <span style=''>need</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3611111111111111);'>reinforcement</span> <span style=''>learning</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>heuristic</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333326);'>modification</span> <span style=''>of</span> <span style=''>cross</span> <span style=''>entropy</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.4117647058823529);'>modifying</span> <span style=''>the</span> <span style=''>training</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>competitive</span> <span style=''>neural</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>coreference</span> <span style=''>system</span> <span style=''>we</span> <span style=''>obtain</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3076923076923076);'>substantial</span> <span style=''>gain</span> <span style=''>in</span> <span style='background-color:rgba(0 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Low</span> <span style=''>rank</span> <span style=''>and</span> <span style=''>Adaptive</span> <span style=''>Sparse</span> <span style=''>Signal</span> <span style=''>(LASSI)</span> <span style=''>Models</span> <span style=''>for</span> <span style=''>Highly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Accelerated</span> <span style=''>Dynamic</span> <span style=''>Imaging</span> <br/><br/><span style=''>Sparsity</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>have</span> <span style=''>been</span> <span style=''>popular</span> <span style=''>in</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>in</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>and</span> <span style=''>imaging</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Compressed</span> <span style=''>sensing</span> <span style=''>exploits</span> <span style=''>the</span> <span style=''>sparsity</span> <span style=''>of</span> <span style=''>images</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transform</span> <span style=''>domain</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dictionary</span> <span style=''>to</span> <span style=''>improve</span> <span style=''>image</span> <span style=''>recovery</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>undersampled</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>measurements</span> <span style=''>In</span> <span style=''>the</span> <span style=''>context</span> <span style=''>of</span> <span style=''>inverse</span> <span style=''>problems</span> <span style=''>in</span> <span style=''>dynamic</span> <span style=''>imaging</span> <span style=''>recent</span> <span style=''>research</span> <span style=''>has</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrated</span> <span style=''>the</span> <span style=''>promise</span> <span style=''>of</span> <span style=''>sparsity</span> <span style=''>and</span> <span style=''>low</span> <span style=''>rank</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>For</span> <span style=''>example</span> <span style=''>the</span> <span style=''>patches</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style=''>data</span> <span style=''>are</span> <span style=''>modeled</span> <span style=''>as</span> <span style=''>sparse</span> <span style=''>in</span> <span style=''>an</span> <span style=''>adaptive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dictionary</span> <span style=''>domain</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resulting</span> <span style=''>image</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dictionary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>undersampled</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>measurements</span> <span style=''>is</span> <span style=''>called</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dictionary</span> <span style=''>blind</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>compressed</span> <span style=''>sensing</span> <span style=''>or</span> <span style=''>the</span> <span style=''>dynamic</span> <span style=''>image</span> <span style=''>sequence</span> <span style=''>is</span> <span style=''>modeled</span> <span style=''>as</span> <span style=''>a</span> <span style=''>sum</span> <span style=''>of</span> <span style=''>low ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.33333333333333326);'>Sketching</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Kronecker</span> <span style=''>Product</span> <span style='background-color:rgba(255, 0, 0, 0.5173824130879345);'>Regression</span> <span style=''>and</span> <span style=''>P</span> <span style=''>splines</span> <br/><br/><span style=''>TensorSketch</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333326);'>oblivious</span> <span style=''>linear</span> <span style=''>sketch</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduced</span> <span style=''>in</span> <span style=''>Pagh13</span> <span style=''>and</span> <span style=''>later</span> <span style=''>used</span> <span style=''>in</span> <span style=''>Pham</span> <span style=''>Pagh13</span> <span style=''>in</span> <span style=''>the</span> <span style=''>context</span> <span style=''>of</span> <span style=''>SVMs</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>polynomial</span> <span style=''>kernels</span> <span style=''>It</span> <span style=''>was</span> <span style=''>shown</span> <span style=''>in</span> <span style=''>Avron</span> <span style=''>Nguyen</span> <span style=''>Woodruff14</span> <span style=''>that</span> <span style=''>TensorSketch</span> <span style=''>provides</span> <span style=''>a</span> <span style=''>subspace</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>embedding</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>therefore</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>canonical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correlation</span> <span style=''>analysis</span> <span style=''>low</span> <span style=''>rank</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>principal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>component</span> <span style='background-color:rgba(255, 0, 0, 0.5173824130879345);'>regression</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>polynomial</span> <span style=''>kernel</span> <span style=''>We</span> <span style=''>take</span> <span style=''>TensorSketch</span> <span style=''>outside</span> <span style=''>of</span> <span style=''>the</span> <span style=''>context</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>polynomials</span> <span style=''>kernels</span> <span style=''>and</span> <span style=''>show</span> <span style=''>its</span> <span style=''>utility</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>in</span> <span style=''>which</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>underlying</span> <span style=''>design</span> <span style=''>matrix</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Kronecker</span> <span style=''>product</span> <span style=''>of</span> <span style=''>smaller</span> <span style=''>matrices</span> <span style=''>This</span> <span style=''>allows</span> <span style=''>us</span> <span style=''>to</span> <span style=''>solve</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Kronecker</span> <span style=''>product</span> <span style='background-color:rgba(255, 0, 0, 0.5173824130879345);'>regression</span> <span style=''>and</span> <span style=''>non</span> <span style=''>negative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Kronecker</span> <span style=''>product</span> <span style='background-color:rgba(255, 0, ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Hierarchical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Adversarially</span> <span style=''>Learned</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hierarchical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generative</span> <span style=''>model</span> <span style=''>with</span> <span style=''>a</span> <span style=''>simple</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Markovian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>and</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corresponding</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>model</span> <span style=''>Both</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generative</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>model</span> <span style=''>are</span> <span style=''>trained</span> <span style=''>using</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adversarial</span> <span style=''>learning</span> <span style=''>paradigm</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hierarchical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>supports</span> <span style=''>the</span> <span style=''>learning</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>progressively</span> <span style=''>more</span> <span style=''>abstract</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>providing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>semantically</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>meaningful</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reconstructions</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>levels</span> <span style=''>of</span> <span style=''>fidelity</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Furthermore</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimizing</span> <span style=''>the</span> <span style=''>Jensen</span> <span style=''>Shanon</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>divergence</span> <span style=''>between</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generative</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>network</span> <span style=''>is</span> <span style=''>enough</span> <span style=''>to</span> <span style=''>minimize</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reconstruction</span> <span style=''>error</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resulting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>semantically</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>meaningful</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hierarchical</span> <span style=''>latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discovery</span> <span style=''>i ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	challenging (0.10258249641319943)
# 	processing (0.10437589670014347)
# 	architecture (0.08931133428981348)
# 	segmentation (0.07173601147776183)
# 	experimental (0.14203730272596843)
# 	different (0.2704447632711621)
# 	detection (0.12804878048780488)
# 	information (0.26398852223816355)
# 	convolutional (0.14275466284074606)
# 	recognition (0.14239598278335724)
#
# Some Statistics words are:
# 	variational (0.09642147117296222)
# 	stochastic (0.1327037773359841)
# 	theoretical (0.1466202783300199)
# 	statistical (0.1550695825049702)
# 	distribution (0.17196819085487078)
# 	variables (0.1496023856858847)
# 	estimation (0.17594433399602386)
# 	dimensional (0.18439363817097415)
# 	inference (0.20228628230616302)
# 	regression (0.18439363817097415)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="60df754a-da5e-44af-b80c-b1425c405b75" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("60df754a-da5e-44af-b80c-b1425c405b75")) {                    Plotly.newPlot(                        "60df754a-da5e-44af-b80c-b1425c405b75",                        [{"x":["recognition","performance","annotators","baselines","classification","specifically","algorithmic","conjecture","introduce","reasoning","consistent","techniques","challenges","annotation","including","surprisingly","annotations","information","community","segmentation","statistics","structure","unreasonable","detection","especially","processing","guarantee","algorithm","compression","according","technique","facilitate","multiples","redundancy","predefined","transform","transformation","criterion","differences","challenging","classifier","represent","activities","verifiable","automatically","establishes","classifiers","anticipate","population","statements","supervised","promising","incorporate","nonlinear","aggregation","inference","describing","implementation","occurring","dirichlet","experiments","neighborhood","prediction","corresponds","coherence","intricate","supervisory","interpretability","procedure","embedding","relationship","correspond","extending","frequently","performing","allocation","approximate","outperforms","strategies","improvement","variables","simulated","representing","linguistic","knowledge","counterpart","effective","significantly","effectively","predicate","linguistically","grounding","framework","application","extracted","operating","typically","selection","autonomous","decisions","interprets","parameters","generated","construction","interesting","parallels","directions","equivalence","introduced","relations","summarises","asymptotic","investigation","dependent","structuring","combining","morphological","computing","filtering","equations","structures","particularly","extensions","confirmed","differential","inferences","conditioning","intractable","traditionally","properties","simulations","conditional","likelihood","distribution","preliminary","computation","statistical","posterior","simulation","parametric","representation","estimation","likelihoods","predictions","algorithms","critically","probability","unlabeled","adversarial","leverages","experimental","predicted","demonstrate","trustworthy","discriminator","cityscapes","differentiate","discriminators","providing","convolutional","additional","consideration","resolution","discovering","effectiveness","advantage","reinforcement","currently","introduction","optimisation","represents","previously","asynchronous","advantages","understanding","highlight","expensive","dominated","repetitive","locations","auxiliary","increases","curriculum","difficulty","spatiotemporal","incorrect","similarities","placement","qualitative","ambiguous","gradually","inconsistencies","presently","extensive","quantitative","retrieval","characteristics","embeddings","individual","representations","demonstrated","available","outperforming","maximization","controllers","variational","expectation","constructed","benchmark","controller","efficient","considers","decentralized","sequences","additionally","described","encompass","predictable","assumptions","processes","applications","concurrently","potential","guarantees","direction","optimization","presented","encountered","particular","competing","customers","eliciting","requirements","development","specification","convenient","functions","generates","requirement","automated","attributes","incorporated","transferable","allocated","unnormalized","approximation","correctly","implement","irregularly","mislabeled","statistic","robustness","dimensional","ultrametric","intrinsical ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	mislabeled
# 	thetastar
# 	ingenious
# 	timelines
# 	maturation
# 	quadrature
# 	smoothers
# 	lightspeed
# 	interestingness
# 	marginalization
# 	repulsion
# 	asynchronously
# 	spectrometry
# 	cardiovascular
# 	delineates
# 	changepoints
# 	recoverability
# 	dendrogram
# 	psychiatric
# 	tightness
# Some words which never appear in Statistics papers:
# 	multiples
# 	linguistically
# 	trustworthy
# 	cityscapes
# 	repetitive
# 	inconsistencies
# 	presently
# 	allocated
# 	localizing
# 	concatenating
# 	insufficiently
# 	multimodality
# 	sensorimotor
# 	maneuvers
# 	milliseconds
# 	contenders
# 	objectness
# 	broadcast
# 	broadcasts
# 	formalisms

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.079102133817779e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7316666666666667
