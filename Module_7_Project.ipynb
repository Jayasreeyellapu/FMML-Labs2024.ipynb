# %% [markdown]
# <a href="https://colab.research.google.com/github/Jayasreeyellapu/FMML-Labs2024.ipynb/blob/main/Module_7_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Module 7 Project: Movie Recommendation Engine

# %% [markdown]
# `Module Coordinator: Ganesh Chandan`

# %% [markdown]
# In this module, we will try to create a Movie Recommendation System using different unsupervised learning techniques.

# %%
# dataset download

# !wget https://files.grouplens.org/datasets/movielens/ml-100k.zip
# !wget https://files.grouplens.org/datasets/movielens/ml-latest-small.zip
# !unzip ml-latest-small.zip
# Out:
# --2025-02-22 07:33:13--  https://files.grouplens.org/datasets/movielens/ml-latest-small.zip
# Resolving files.grouplens.org (files.grouplens.org)... 128.101.65.152
# Connecting to files.grouplens.org (files.grouplens.org)|128.101.65.152|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 978202 (955K) [application/zip]
# Saving to: ‘ml-latest-small.zip’
#
# ml-latest-small.zip 100%[===================>] 955.28K  2.44MB/s    in 0.4s
#
# 2025-02-22 07:33:14 (2.44 MB/s) - ‘ml-latest-small.zip’ saved [978202/978202]
#
# Archive:  ml-latest-small.zip
#    creating: ml-latest-small/
#   inflating: ml-latest-small/links.csv
#   inflating: ml-latest-small/tags.csv
#   inflating: ml-latest-small/ratings.csv
#   inflating: ml-latest-small/README.txt
#   inflating: ml-latest-small/movies.csv

# %% [markdown]
# ## Clustering based recommendation

# %%
# Import Libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.sparse import csr_matrix
from mpl_toolkits.axes_grid1 import make_axes_locatable
from sklearn.cluster import KMeans
from sklearn.metrics import mean_squared_error
import itertools
from sklearn.metrics import silhouette_samples, silhouette_score

# %%
# Import the Movies dataset
movies = pd.read_csv('ml-latest-small/movies.csv')
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
# Import the ratings dataset
ratings = pd.read_csv('ml-latest-small/ratings.csv')
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
# Print the number of records and the total number of movies
print('The dataset contains: ', len(ratings), ' ratings of ', len(movies), ' movies.')
# Out:
# The dataset contains:  100836  ratings of  9742  movies.

# %% [markdown]
# ### Romance versus Science Fiction
#
# We will start by considering a subset of users and discovering what are their favourite genre. We will do this by defining a function that will calculate each user’s average rating for all science fiction and romance movies.

# %%
# Function to get the genre ratings
def get_genre_ratings(ratings, movies, genres, column_names):
    genre_ratings = pd.DataFrame()
    for genre in genres:
        genre_movies = movies[movies['genres'].str.contains(genre) ]
        avg_genre_votes_per_user = ratings[ratings['movieId'].isin(genre_movies['movieId'])].loc[:, ['userId', 'rating']].groupby(['userId'])['rating'].mean().round(2)

        genre_ratings = pd.concat([genre_ratings, avg_genre_votes_per_user], axis=1)

    genre_ratings.columns = column_names
    return genre_ratings# Calculate the average rating of romance and scifi movies
genre_ratings = get_genre_ratings(ratings, movies, ['Romance', 'Sci-Fi'], ['avg_romance_rating', 'avg_scifi_rating'])
genre_ratings.head()
# Out:
#    avg_romance_rating  avg_scifi_rating
# 1                4.31              4.22
# 2                4.50              3.88
# 3                0.50              4.20
# 4                3.38              2.83
# 5                3.09              2.50

# %% [markdown]
# In order to have a more delimited subset of people to study, we are going to bias our grouping to only get ratings from those users that like either romance or science fiction movies.

# %%
# Function to get the biased dataset
def bias_genre_rating_dataset(genre_ratings, score_limit_1, score_limit_2):
    biased_dataset =    genre_ratings[((genre_ratings['avg_romance_rating'] < score_limit_1 - 0.2) & (genre_ratings['avg_scifi_rating'] > score_limit_2)) | ((genre_ratings['avg_scifi_rating'] < score_limit_1) & (genre_ratings['avg_romance_rating'] > score_limit_2))]
    biased_dataset = pd.concat([biased_dataset[:300], genre_ratings[:2]])
    biased_dataset = pd.DataFrame(biased_dataset.to_records())
    return biased_dataset

# Bias the dataset
biased_dataset = bias_genre_rating_dataset(genre_ratings, 3.2, 2.5)

# Printing the resulting number of records & the head of the dataset
print( "Number of records: ", len(biased_dataset))
biased_dataset.head()
# Out:
# Number of records:  162
#    index  avg_romance_rating  avg_scifi_rating
# 0      3                0.50              4.20
# 1      4                3.38              2.83
# 2      5                3.09              2.50
# 3      7                2.65              3.15
# 4      9                3.17              3.00

# %%
# Defining the scatterplot drawing function
def draw_scatterplot(x_data, x_label, y_data, y_label):
    fig = plt.figure(figsize=(8,8))
    ax = fig.add_subplot(111)
    plt.xlim(0, 5)
    plt.ylim(0, 5)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    ax.scatter(x_data, y_data, s=30)

# Plot the scatterplot
draw_scatterplot(biased_dataset['avg_scifi_rating'],'Avg scifi rating', biased_dataset['avg_romance_rating'], 'Avg romance rating')

# %%
# Let's turn our dataset into a list
X = biased_dataset[['avg_scifi_rating','avg_romance_rating']].values

# Import KMeans
from sklearn.cluster import KMeans

# Create an instance of KMeans to find two clusters
kmeans_1 = KMeans(n_clusters=2)

# Use fit_predict to cluster the dataset
predictions = kmeans_1.fit_predict(X)

# Defining the cluster plotting function
def draw_clusters(biased_dataset, predictions, cmap='viridis'):
    fig = plt.figure(figsize=(8,8))
    ax = fig.add_subplot(111)
    plt.xlim(0, 5)
    plt.ylim(0, 5)
    ax.set_xlabel('Avg scifi rating')
    ax.set_ylabel('Avg romance rating')
    clustered = pd.concat([biased_dataset.reset_index(), pd.DataFrame({'group':predictions})], axis=1)
    plt.scatter(clustered['avg_scifi_rating'], clustered['avg_romance_rating'], c=clustered['group'], s=20, cmap=cmap)

# Plot
draw_clusters(biased_dataset, predictions)

# %%
# Create an instance of KMeans to find three clusters
kmeans_2 = KMeans(n_clusters=3)
# Use fit_predict to cluster the dataset
predictions_2 = kmeans_2.fit_predict(X)
# Plot
draw_clusters(biased_dataset, predictions_2)

# %% [markdown]
# It is evident now that the science-fiction rating has started to come into play:
#
#     People who like sci-fi and romance modeately belong to the green group.
#     People who like scifi but not romance belong to the yello group.
#     People who like romance but not sci-fi belong to the purple group.

# %% [markdown]
# Finding optimal clusters using silhouette score

# %%
# Selecting our dataset to study
df = biased_dataset[['avg_scifi_rating','avg_romance_rating']]

# Choose the range of k values to test.
# We added a stride of 5 to improve performance. We don't need to calculate the error for every k value
possible_k_values = range(2, len(X)+1, 5)

# Define function to calculate the clustering errors
def clustering_errors(k, data):
    kmeans = KMeans(n_clusters=k).fit(data)
    predictions = kmeans.predict(data)
    #cluster_centers = kmeans.cluster_centers_
    # errors = [mean_squared_error(row, cluster_centers[cluster]) for row, cluster in zip(data.values, predictions)]
    # return sum(errors)
    silhouette_avg = silhouette_score(data, predictions)
    return silhouette_avg

# Calculate error values for all k values we're interested in
errors_per_k = [clustering_errors(k, X) for k in possible_k_values]

# Plot the each value of K vs. the silhouette score at that value
fig, ax = plt.subplots(figsize=(16, 6))
plt.plot(possible_k_values, errors_per_k)

# Ticks and grid
xticks = np.arange(min(possible_k_values), max(possible_k_values)+1, 5.0)
ax.set_xticks(xticks, minor=False)
ax.set_xticks(xticks, minor=True)
ax.xaxis.grid(True, which='both')
yticks = np.arange(round(min(errors_per_k), 2), max(errors_per_k), .05)
ax.set_yticks(yticks, minor=False)
ax.set_yticks(yticks, minor=True)
ax.yaxis.grid(True, which='both')
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:1389: ConvergenceWarning: Number of distinct clusters (157) found smaller than n_clusters (162). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)

# %% [markdown]
# We will chose the K = 7 as it is the one that yields the best score and will be easier to visualize.

# %%
# Create an instance of KMeans to find seven clusters
kmeans_4 = KMeans(n_clusters=7)
# Use fit_predict to cluster the dataset
predictions_4 = kmeans_4.fit_predict(X)
# Plot
draw_clusters(biased_dataset, predictions_4, cmap='Accent')

# %% [markdown]
# Up to now, we have only analyzed romance and science-fiction movies. Let us see what happens when adding other genre to our analysis by adding Action movies.

# %%
# Select our biased dataset and add action genre
biased_dataset_3_genres = get_genre_ratings(ratings, movies, ['Romance','Sci-Fi', 'Action'],
['avg_romance_rating', 'avg_scifi_rating', 'avg_action_rating'])
# Drop null values
biased_dataset_3_genres = bias_genre_rating_dataset(biased_dataset_3_genres, 3.2, 2.5).dropna()
# Print the number of records and the head of our dataset
print( "Number of records: ", len(biased_dataset_3_genres))
biased_dataset_3_genres.head()
# Out:
# Number of records:  161
#    index  avg_romance_rating  avg_scifi_rating  avg_action_rating
# 0      3                0.50              4.20               3.57
# 1      4                3.38              2.83               3.32
# 2      5                3.09              2.50               3.11
# 3      7                2.65              3.15               3.26
# 4      9                3.17              3.00               3.12

# %%
# Turn dataset into a list
X_with_action = biased_dataset_3_genres[['avg_scifi_rating','avg_romance_rating','avg_action_rating']].values# Create an instance of KMeans to find seven clusters
kmeans_5 = KMeans(n_clusters=7)
# Use fit_predict to cluster the dataset
predictions_5 = kmeans_5.fit_predict(X_with_action)
# Define 3d plotting function
def draw_clusters_3d(biased_dataset_3, predictions):
    fig = plt.figure(figsize=(8,8))
    ax = fig.add_subplot(111)
    plt.xlim(0, 5)
    plt.ylim(0, 5)
    ax.set_xlabel('Avg scifi rating')
    ax.set_ylabel('Avg romance rating')
    clustered = pd.concat([biased_dataset_3.reset_index(), pd.DataFrame({'group':predictions})], axis=1)
    colors = itertools.cycle(plt.rcParams["axes.prop_cycle"].by_key()["color"])
    for g in clustered.group.unique():
        color = next(colors)
        for index, point in clustered[clustered.group == g].iterrows():
            if point['avg_action_rating'].astype(float) > 3:
                size = 50
            else:
                size = 15
            plt.scatter(point['avg_scifi_rating'],
                        point['avg_romance_rating'],
                        s=size,
                        color=color)# Plot
draw_clusters_3d(biased_dataset_3_genres, predictions_5)

# %% [markdown]
# The size of the dots represent the ratings of the action movies.

# %% [markdown]
# # Exercise 1
#
# ## Instead of choosing a n_clusters as 7, play around with different k
# ## Find the optimal no of clusters with 3 genre_ratings data we just created using silhouette score method

# %%
#CODE
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

# Sample dataset: Replace this with actual data
np.random.seed(42)
genre_ratings = pd.DataFrame(
    np.random.rand(100, 5),  # 100 samples, 5 features
    columns=['Action', 'Comedy', 'Drama', 'Horror', 'Sci-Fi']
)

# Normalize the data
scaler = StandardScaler()
genre_ratings_scaled = scaler.fit_transform(genre_ratings)

# Range of clusters to test
k_values = range(2, 11)  # Testing k from 2 to 10
silhouette_scores = []

for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init='auto')  # Use 'auto' to avoid warnings
    cluster_labels = kmeans.fit_predict(genre_ratings_scaled)

    # Compute silhouette score only if valid
    if len(set(cluster_labels)) > 1:
        silhouette_avg = silhouette_score(genre_ratings_scaled, cluster_labels)
    else:
        silhouette_avg = -1  # Invalid clustering case

    silhouette_scores.append(silhouette_avg)

# Find the optimal k (max silhouette score)
optimal_k = k_values[np.argmax(silhouette_scores)]
print(f"Optimal number of clusters: {optimal_k}")

# Plot Silhouette Scores
plt.figure(figsize=(8, 5))
plt.plot(k_values, silhouette_scores, marker='o', linestyle='--', color='b')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.title('Optimal K using Silhouette Score')
plt.grid(True)
plt.show()
# Out:
# Optimal number of clusters: 9

# %% [markdown]
# ### Taking users into consideration

# %% [markdown]
# Once we have seen and understood how the K-Means algorithm group the users by their movie genre preferences, we are going to take a bigger picture of the dataset and explore how users rate individual movies.
#
# To do so, we will subset the dataset by ‘userid’ vs ‘user rating’ as follows.

# %%
# Merge the two tables then pivot so we have Users X Movies dataframe
ratings_title = pd.merge(ratings, movies[['movieId', 'title']], on='movieId' )
user_movie_ratings = pd.pivot_table(ratings_title, index='userId', columns= 'title', values='rating')

# Print he number of dimensions and a subset of the dataset
print('dataset dimensions: ', user_movie_ratings.shape, '\n\nSubset example:')
user_movie_ratings.iloc[:6, :10]
# Out:
# dataset dimensions:  (610, 9719)
#
# Subset example:
# title   '71 (2014)  'Hellboy': The Seeds of Creation (2004)  \
# userId
# 1              NaN                                      NaN
# 2              NaN                                      NaN
# 3              NaN                                      NaN
# 4              NaN                                      NaN
# 5              NaN                                      NaN
# 6              NaN                                      NaN
#
# title   'Round Midnight (1986)  'Salem's Lot (2004)  \
# userId
# 1                          NaN                  NaN
# 2                          NaN                  NaN
# 3                          NaN                  NaN
# 4                          NaN                  NaN
# 5                          NaN                  NaN
# 6                          NaN                  NaN
#
# title   'Til There Was You (1997)  'Tis the Season for Love (2015)  \
# userId
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                              NaN
# 4                             NaN                              NaN
# 5                             NaN                              NaN
# 6                             NaN                              NaN
#
# title   'burbs, The (1989)  'night Mother (1986)  (500) Days of Summer (2009)  \
# userId
# 1                      NaN                   NaN                          NaN
# 2                      NaN                   NaN                          NaN
# 3                      NaN                   NaN                          NaN
# 4                      NaN                   NaN                          NaN
# 5                      NaN                   NaN                          NaN
# 6                      NaN                   NaN                          NaN
#
# title   *batteries not included (1987)
# userId
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# 5                                  NaN
# 6                                  NaN

# %%
# Define Function to get the most rated movies
def get_most_rated_movies(user_movie_ratings, max_number_of_movies):
    # 1- Count
    # Instead of append, use concat to add a row with counts
    counts = user_movie_ratings.count().to_frame().T
    user_movie_ratings = pd.concat([user_movie_ratings, counts], ignore_index=True)
    # 2- sort
    user_movie_ratings_sorted = user_movie_ratings.sort_values(len(user_movie_ratings)-1, axis=1, ascending=False)
    user_movie_ratings_sorted = user_movie_ratings_sorted.drop(user_movie_ratings_sorted.tail(1).index)
    # 3- slice
    most_rated_movies = user_movie_ratings_sorted.iloc[:, :max_number_of_movies]
    return most_rated_movies

# %%
# Define Function to get the most rated movies
def get_most_rated_movies(user_movie_ratings, max_number_of_movies):
    # 1- Count
    # Instead of append, use concat to add a row with counts
    counts = user_movie_ratings.count().to_frame().T
    user_movie_ratings = pd.concat([user_movie_ratings, counts], ignore_index=True)
    # 2- sort
    user_movie_ratings_sorted = user_movie_ratings.sort_values(len(user_movie_ratings)-1, axis=1, ascending=False)
    user_movie_ratings_sorted = user_movie_ratings_sorted.drop(user_movie_ratings_sorted.tail(1).index)
    # 3- slice
    most_rated_movies = user_movie_ratings_sorted.iloc[:, :max_number_of_movies]
    return most_rated_movies
# Define the plotting heatmap function
def draw_movies_heatmap(most_rated_movies_users_selection, axis_labels=True):

    fig = plt.figure(figsize=(15,4))
    ax = plt.gca()

    # Draw heatmap
    heatmap = ax.imshow(most_rated_movies_users_selection,  interpolation='nearest', vmin=0, vmax=5, aspect='auto')
    if axis_labels:
        ax.set_yticks(np.arange(most_rated_movies_users_selection.shape[0]) , minor=False)
        ax.set_xticks(np.arange(most_rated_movies_users_selection.shape[1]) , minor=False)
        ax.invert_yaxis()
        ax.xaxis.tick_top()
        labels = most_rated_movies_users_selection.columns.str[:40]
        ax.set_xticklabels(labels, minor=False)
        ax.set_yticklabels(most_rated_movies_users_selection.index, minor=False)
        plt.setp(ax.get_xticklabels(), rotation=90)
    else:
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

    ax.grid(False)
    ax.set_ylabel('User id')# Separate heatmap from color bar
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.05)# Color bar
    cbar = fig.colorbar(heatmap, ticks=[5, 4, 3, 2, 1, 0], cax=cax)
    cbar.ax.set_yticklabels(['5 stars', '4 stars','3 stars','2 stars','1 stars','0 stars'])
    plt.show()
# Assuming user_movie_ratings is already defined
most_rated_movies_users_selection = get_most_rated_movies(user_movie_ratings, 20) # Get top 20 rated movies
# Print the heatmap
draw_movies_heatmap(most_rated_movies_users_selection) # Call draw_movies_heatmap with the calculated data

# %%
# Pivot the dataset and choose the first 1000 movies
user_movie_ratings =  pd.pivot_table(ratings_title, index='userId', columns= 'title', values='rating')
most_rated_movies_1k = get_most_rated_movies(user_movie_ratings, 1000).replace(np.nan, 0)

# %%
from scipy import sparse

# Conversion to sparse csr matrix
sparse_ratings = sparse.csr_matrix(most_rated_movies_1k.values)

# %% [markdown]
# ### Large Scale Clustering

# %%
# 20 clusters
predictions = KMeans(n_clusters=20, algorithm='lloyd').fit_predict(sparse_ratings) # Changed algorithm to 'lloyd'
# Select the mas number of users and movies heatmap cluster
# Cluster and print some of them
clustered = pd.concat([get_most_rated_movies(user_movie_ratings, 1000).reset_index(), pd.DataFrame({'group':predictions})], axis=1)
# draw_movie_clusters(clustered, max_users, max_movies)

# %% [markdown]
# ### Predictions and Recommendation

# %%
# Pick a cluster ID from the clusters above
cluster_number = 11
# Let's filter to only see the region of the dataset with the most number of values
n_users = 75
n_movies = 300
cluster = clustered[clustered.group == cluster_number].drop(['index', 'group'], axis=1)
print(cluster)

# Define the sort_by_rating_density function
def sort_by_rating_density(cluster, n_movies, n_users):
    # Calculate rating density for each movie
    rating_density = cluster.sum().div(cluster.count()).sort_values(ascending=False)

    # Get the top n_movies with highest rating density
    top_movies = rating_density.index[:n_movies]

    # Filter the cluster based on top movies and top n_users
    cluster_filtered = cluster.loc[cluster.index[:n_users], top_movies]

    return cluster_filtered

# Sort and print the cluster
cluster = sort_by_rating_density(cluster, n_movies, n_users)
draw_movies_heatmap(cluster, axis_labels=False)
# Out:
#      Forrest Gump (1994)  Shawshank Redemption, The (1994)  \
# 14                   5.0                               5.0
# 20                   4.5                               NaN
# 51                   5.0                               5.0
# 72                   NaN                               NaN
# 79                   NaN                               5.0
# 118                  4.0                               4.5
# 124                  5.0                               4.0
# 128                  NaN                               NaN
# 138                  NaN                               NaN
# 140                  4.0                               4.0
# 209                  NaN                               NaN
# 210                  4.5                               5.0
# 211                  3.5                               4.5
# 226                  5.0                               4.0
# 232                  5.0                               5.0
# 245                  3.5                               NaN
# 246                  5.0                               4.5
# 255                  NaN                               5.0
# 278                  3.0                               4.5
# 330                  NaN                               5.0
# 364                  4.5                               4.5
# 381                  4.5                               5.0
# 392                  NaN                               NaN
# 407                  NaN                               4.5
# 431                  4.5                               3.0
# 459                  4.5                               5.0
# 465                  5.0                               3.0
# 474                  NaN                               NaN
# 494                  4.0                               5.0
# 508                  NaN                               NaN
# 521                  3.5                               5.0
# 533                  4.5                               NaN
# 550                  4.5                               4.0
# 566                  3.0                               NaN
# 581                  NaN                               NaN
# 585                  NaN                               5.0
# 595                  3.5                               NaN
# 600                  NaN                               5.0
#
#      Pulp Fiction (1994)  Silence of the Lambs, The (1991)  \
# 14                   4.0                               NaN
# 20                   3.5                               NaN
# 51                   NaN                               NaN
# 72                   NaN                               NaN
# 79                   NaN                               5.0
# 118                  4.0                               NaN
# 124                  4.5                               4.0
# 128                  NaN                               NaN
# 138                  NaN                               NaN
# 140                  4.0                               NaN
# 209                  0.5                               NaN
# 210                  4.5                               NaN
# 211                  3.5                               3.5
# 226                  4.5                               4.5
# 232                  4.0                               4.5
# 245                  4.0                               NaN
# 246                  4.0                               4.0
# 255                  NaN                               4.5
# 278                  5.0                               4.0
# 330                  5.0                               5.0
# 364                  NaN                               0.5
# 381                  5.0                               5.0
# 392                  NaN                               NaN
# 407                  NaN                               NaN
# 431                  2.5                               4.0
# 459                  NaN                               NaN
# 465                  NaN                               NaN
# 474                  NaN                               NaN
# 494                  NaN                               NaN
# 508                  3.5                               NaN
# 521                  5.0                               NaN
# 533                  NaN                               4.0
# 550                  3.5                               4.5
# 566                  NaN                               NaN
# 581                  NaN                               4.0
# 585                  NaN                               NaN
# 595                  NaN                               4.0
# 600                  NaN                               NaN
#
#      Matrix, The (1999)  Star Wars: Episode IV - A New Hope (1977)  \
# 14                  4.0                                        5.0
# 20                  4.0                                        4.5
# 51                  5.0                                        4.0
# 72                  NaN                                        2.0
# 79                  4.5                                        NaN
# 118                 4.0                                        NaN
# 124                 5.0                                        NaN
# 128                 4.5                                        4.0
# 138                 NaN                                        4.0
# 140                 3.5                                        4.0
# 209                 5.0                                        5.0
# 210                 5.0                                        4.5
# 211                 3.0                                        2.5
# 226                 4.5                                        3.5
# 232                 4.5                                        NaN
# 245                 5.0                                        5.0
# 246                 3.5                                        4.0
# 255                 4.5                                        4.0
# 278                 4.5                                        5.0
# 330                 NaN                                        NaN
# 364                 NaN                                        3.0
# 381                 5.0                                        5.0
# 392                 5.0                                        NaN
# 407                 4.5                                        4.0
# 431                 3.5                                        3.5
# 459                 4.5                                        NaN
# 465                 4.0                                        1.5
# 474                 4.5                                        5.0
# 494                 5.0                                        NaN
# 508                 3.5                                        4.0
# 521                 4.0                                        5.0
# 533                 4.0                                        4.5
# 550                 4.0                                        3.5
# 566                 NaN                                        2.0
# 581                 5.0                                        4.0
# 585                 5.0                                        4.5
# 595                 4.0                                        4.0
# 600                 5.0                                        NaN
#
#      Jurassic Park (1993)  Braveheart (1995)  \
# 14                    NaN                NaN
# 20                    4.0                NaN
# 51                    NaN                NaN
# 72                    NaN                NaN
# 79                    NaN                NaN
# 118                   NaN                NaN
# 124                   NaN                4.5
# 128                   3.5                4.0
# 138                   NaN                NaN
# 140                   3.0                3.5
# 209                   NaN                NaN
# 210                   NaN                NaN
# 211                   3.0                NaN
# 226                   NaN                3.5
# 232                   NaN                3.0
# 245                   NaN                NaN
# 246                   4.5                4.0
# 255                   NaN                NaN
# 278                   4.0                4.0
# 330                   NaN                NaN
# 364                   NaN                NaN
# 381                   NaN                NaN
# 392                   NaN                4.0
# 407                   NaN                NaN
# 431                   4.5                4.0
# 459                   NaN                NaN
# 465                   NaN                NaN
# 474                   NaN                NaN
# 494                   NaN                NaN
# 508                   NaN                NaN
# 521                   3.5                4.0
# 533                   4.5                NaN
# 550                   NaN                3.5
# 566                   2.0                NaN
# 581                   NaN                NaN
# 585                   NaN                5.0
# 595                   NaN                NaN
# 600                   NaN                NaN
#
#      Terminator 2: Judgment Day (1991)  Schindler's List (1993)  ...  \
# 14                                 5.0                      5.0  ...
# 20                                 3.5                      NaN  ...
# 51                                 NaN                      NaN  ...
# 72                                 NaN                      NaN  ...
# 79                                 NaN                      NaN  ...
# 118                                NaN                      NaN  ...
# 124                                4.0                      NaN  ...
# 128                                NaN                      NaN  ...
# 138                                NaN                      NaN  ...
# 140                                NaN                      NaN  ...
# 209                                4.0                      NaN  ...
# 210                                NaN                      NaN  ...
# 211                                4.0                      NaN  ...
# 226                                3.5                      4.0  ...
# 232                                NaN                      4.0  ...
# 245                                5.0                      NaN  ...
# 246                                3.5                      4.0  ...
# 255                                NaN                      NaN  ...
# 278                                4.0                      NaN  ...
# 330                                NaN                      NaN  ...
# 364                                NaN                      NaN  ...
# 381                                NaN                      5.0  ...
# 392                                0.5                      NaN  ...
# 407                                NaN                      NaN  ...
# 431                                3.5                      4.5  ...
# 459                                NaN                      NaN  ...
# 465                                NaN                      NaN  ...
# 474                                5.0                      NaN  ...
# 494                                NaN                      4.0  ...
# 508                                NaN                      NaN  ...
# 521                                NaN                      NaN  ...
# 533                                NaN                      NaN  ...
# 550                                4.0                      NaN  ...
# 566                                NaN                      NaN  ...
# 581                                NaN                      NaN  ...
# 585                                5.0                      2.5  ...
# 595                                3.0                      4.0  ...
# 600                                NaN                      5.0  ...
#
#      Pay It Forward (2000)  Buffy the Vampire Slayer (1992)  Arrival (2016)  \
# 14                     NaN                              NaN             NaN
# 20                     NaN                              NaN             4.0
# 51                     NaN                              NaN             NaN
# 72                     4.0                              NaN             NaN
# 79                     NaN                              NaN             NaN
# 118                    NaN                              NaN             NaN
# 124                    NaN                              NaN             3.5
# 128                    NaN                              NaN             NaN
# 138                    0.5                              NaN             NaN
# 140                    NaN                              NaN             NaN
# 209                    NaN                              NaN             NaN
# 210                    NaN                              3.0             NaN
# 211                    NaN                              NaN             NaN
# 226                    NaN                              NaN             NaN
# 232                    NaN                              NaN             NaN
# 245                    NaN                              NaN             NaN
# 246                    NaN                              NaN             NaN
# 255                    NaN                              NaN             NaN
# 278                    NaN                              NaN             4.0
# 330                    5.0                              NaN             2.5
# 364                    NaN                              NaN             NaN
# 381                    NaN                              NaN             NaN
# 392                    NaN                              NaN             NaN
# 407                    NaN                              NaN             NaN
# 431                    NaN                              NaN             NaN
# 459                    NaN                              NaN             NaN
# 465                    NaN                              NaN             NaN
# 474                    NaN                              NaN             NaN
# 494                    NaN                              NaN             NaN
# 508                    NaN                              NaN             NaN
# 521                    NaN                              NaN             NaN
# 533                    NaN                              NaN             NaN
# 550                    NaN                              NaN             NaN
# 566                    NaN                              NaN             4.0
# 581                    NaN                              NaN             NaN
# 585                    NaN                              NaN             NaN
# 595                    NaN                              NaN             NaN
# 600                    NaN                              NaN             NaN
#
#      The Hunger Games: Catching Fire (2013)  Scary Movie 2 (2001)  \
# 14                                      NaN                   NaN
# 20                                      4.0                   NaN
# 51                                      NaN                   NaN
# 72                                      NaN                   NaN
# 79                                      NaN                   NaN
# 118                                     NaN                   NaN
# 124                                     NaN                   NaN
# 128                                     NaN                   NaN
# 138                                     NaN                   NaN
# 140                                     NaN                   NaN
# 209                                     NaN                   NaN
# 210                                     NaN                   NaN
# 211                                     NaN                   NaN
# 226                                     NaN                   NaN
# 232                                     NaN                   NaN
# 245                                     NaN                   NaN
# 246                                     NaN                   NaN
# 255                                     4.5                   3.0
# 278                                     NaN                   NaN
# 330                                     NaN                   NaN
# 364                                     NaN                   NaN
# 381                                     NaN                   NaN
# 392                                     NaN                   NaN
# 407                                     NaN                   NaN
# 431                                     NaN                   NaN
# 459                                     NaN                   NaN
# 465                                     NaN                   NaN
# 474                                     4.5                   NaN
# 494                                     NaN                   NaN
# 508                                     3.5                   2.5
# 521                                     NaN                   NaN
# 533                                     NaN                   NaN
# 550                                     4.0                   NaN
# 566                                     2.5                   NaN
# 581                                     NaN                   NaN
# 585                                     3.5                   NaN
# 595                                     NaN                   NaN
# 600                                     NaN                   NaN
#
#      Virgin Suicides, The (1999)  National Lampoon's Vacation (1983)  \
# 14                           NaN                                 NaN
# 20                           NaN                                 NaN
# 51                           NaN                                 NaN
# 72                           NaN                                 NaN
# 79                           NaN                                 NaN
# 118                          NaN                                 NaN
# 124                          NaN                                 NaN
# 128                          5.0                                 NaN
# 138                          NaN                                 NaN
# 140                          NaN                                 NaN
# 209                          NaN                                 NaN
# 210                          NaN                                 NaN
# 211                          NaN                                 NaN
# 226                          NaN                                 NaN
# 232                          NaN                                 NaN
# 245                          3.0                                 NaN
# 246                          NaN                                 NaN
# 255                          NaN                                 NaN
# 278                          NaN                                 NaN
# 330                          NaN                                 NaN
# 364                          NaN                                 NaN
# 381                          NaN                                 NaN
# 392                          NaN                                 NaN
# 407                          NaN                                 NaN
# 431                          NaN                                 NaN
# 459                          NaN                                 NaN
# 465                          NaN                                 NaN
# 474                          NaN                                 NaN
# 494                          NaN                                 NaN
# 508                          NaN                                 NaN
# 521                          NaN                                 NaN
# 533                          NaN                                 NaN
# 550                          NaN                                 NaN
# 566                          NaN                                 NaN
# 581                          NaN                                 NaN
# 585                          NaN                                 NaN
# 595                          NaN                                 NaN
# 600                          NaN                                 NaN
#
#      Muppet Treasure Island (1996)  Last Emperor, The (1987)  Bad Santa (2003)
# 14                             NaN                       NaN               NaN
# 20                             NaN                       NaN               NaN
# 51                             NaN                       NaN               NaN
# 72                             NaN                       NaN               NaN
# 79                             NaN                       NaN               NaN
# 118                            NaN                       NaN               NaN
# 124                            NaN                       NaN               NaN
# 128                            NaN                       NaN               NaN
# 138                            NaN                       NaN               1.5
# 140                            3.5                       NaN               NaN
# 209                            NaN                       NaN               NaN
# 210                            NaN                       NaN               NaN
# 211                            NaN                       NaN               NaN
# 226                            NaN                       NaN               NaN
# 232                            NaN                       NaN               NaN
# 245                            NaN                       NaN               NaN
# 246                            NaN                       NaN               NaN
# 255                            NaN                       NaN               4.0
# 278                            NaN                       NaN               NaN
# 330                            NaN                       NaN               NaN
# 364                            NaN                       NaN               NaN
# 381                            NaN                       NaN               NaN
# 392                            NaN                       NaN               NaN
# 407                            NaN                       NaN               NaN
# 431                            NaN                       NaN               NaN
# 459                            NaN                       NaN               NaN
# 465                            NaN                       NaN               NaN
# 474                            NaN                       NaN               NaN
# 494                            NaN                       NaN               5.0
# 508                            NaN                       NaN               NaN
# 521                            NaN                       NaN               NaN
# 533                            NaN                       NaN               NaN
# 550                            NaN                       NaN               NaN
# 566                            NaN                       NaN               NaN
# 581                            NaN                       NaN               NaN
# 585                            NaN                       NaN               NaN
# 595                            NaN                       NaN               NaN
# 600                            NaN                       NaN               NaN
#
# [38 rows x 1000 columns]

# %%
# Fill in the name of the column/movie. e.g. 'Forrest Gump (1994)'
movie_name = "Matrix, The (1999)"
cluster[movie_name].mean()
# Out:
# 4.378787878787879

# %%
# The average rating of 20 movies as rated by the users in the cluster
cluster.mean().head(20)
# Out:
# Brazil (1985)                                                      5.000000
# Natural Born Killers (1994)                                        5.000000
# Caddyshack (1980)                                                  5.000000
# Spy Game (2001)                                                    5.000000
# Exorcist, The (1973)                                               5.000000
# Lawrence of Arabia (1962)                                          5.000000
# Payback (1999)                                                     5.000000
# Patton (1970)                                                      5.000000
# Singin' in the Rain (1952)                                         5.000000
# Cinema Paradiso (Nuovo cinema Paradiso) (1989)                     5.000000
# Bull Durham (1988)                                                 5.000000
# City of Lost Children, The (Cité des enfants perdus, La) (1995)    5.000000
# Addams Family Values (1993)                                        5.000000
# Road Warrior, The (Mad Max 2) (1981)                               5.000000
# What's Eating Gilbert Grape (1993)                                 5.000000
# Ghost in the Shell (Kôkaku kidôtai) (1995)                         5.000000
# Gods Must Be Crazy, The (1980)                                     5.000000
# The Count of Monte Cristo (2002)                                   4.875000
# Back to the Future Part II (1989)                                  4.857143
# 12 Angry Men (1957)                                                4.750000
# dtype: float64

# %%
cluster
# Out:
#      Brazil (1985)  Natural Born Killers (1994)  Caddyshack (1980)  \
# 14             NaN                          NaN                NaN
# 20             NaN                          NaN                NaN
# 51             NaN                          NaN                NaN
# 72             NaN                          NaN                NaN
# 79             NaN                          NaN                NaN
# 118            NaN                          NaN                NaN
# 124            NaN                          5.0                NaN
# 128            NaN                          NaN                NaN
# 138            NaN                          NaN                NaN
# 140            NaN                          NaN                5.0
# 209            NaN                          NaN                NaN
# 210            NaN                          NaN                NaN
# 211            NaN                          NaN                NaN
# 226            NaN                          NaN                NaN
# 232            NaN                          NaN                NaN
# 245            NaN                          NaN                NaN
# 246            NaN                          NaN                NaN
# 255            NaN                          NaN                NaN
# 278            NaN                          NaN                NaN
# 330            NaN                          NaN                NaN
# 364            NaN                          NaN                NaN
# 381            NaN                          NaN                NaN
# 392            5.0                          NaN                NaN
# 407            NaN                          NaN                5.0
# 431            NaN                          NaN                NaN
# 459            NaN                          NaN                NaN
# 465            NaN                          NaN                NaN
# 474            NaN                          NaN                NaN
# 494            NaN                          NaN                NaN
# 508            NaN                          NaN                NaN
# 521            NaN                          NaN                NaN
# 533            NaN                          NaN                NaN
# 550            NaN                          NaN                NaN
# 566            NaN                          NaN                NaN
# 581            NaN                          NaN                NaN
# 585            NaN                          NaN                NaN
# 595            NaN                          NaN                NaN
# 600            NaN                          NaN                NaN
#
#      Spy Game (2001)  Exorcist, The (1973)  Lawrence of Arabia (1962)  \
# 14               NaN                   NaN                        NaN
# 20               NaN                   NaN                        NaN
# 51               5.0                   NaN                        NaN
# 72               NaN                   NaN                        NaN
# 79               NaN                   NaN                        NaN
# 118              NaN                   NaN                        NaN
# 124              NaN                   NaN                        NaN
# 128              NaN                   NaN                        NaN
# 138              NaN                   NaN                        NaN
# 140              NaN                   NaN                        NaN
# 209              NaN                   NaN                        NaN
# 210              NaN                   NaN                        NaN
# 211              NaN                   NaN                        NaN
# 226              NaN                   NaN                        NaN
# 232              NaN                   NaN                        NaN
# 245              NaN                   NaN                        NaN
# 246              NaN                   NaN                        NaN
# 255              NaN                   NaN                        NaN
# 278              NaN                   NaN                        NaN
# 330              NaN                   NaN                        NaN
# 364              NaN                   NaN                        NaN
# 381              NaN                   NaN                        5.0
# 392              NaN                   NaN                        NaN
# 407              NaN                   NaN                        NaN
# 431              NaN                   5.0                        NaN
# 459              NaN                   NaN                        NaN
# 465              NaN                   NaN                        NaN
# 474              NaN                   NaN                        NaN
# 494              NaN                   NaN                        NaN
# 508              NaN                   NaN                        NaN
# 521              NaN                   NaN                        NaN
# 533              NaN                   NaN                        NaN
# 550              NaN                   NaN                        NaN
# 566              NaN                   NaN                        NaN
# 581              NaN                   NaN                        NaN
# 585              NaN                   NaN                        NaN
# 595              NaN                   NaN                        NaN
# 600              NaN                   NaN                        NaN
#
#      Payback (1999)  Patton (1970)  Singin' in the Rain (1952)  \
# 14              NaN            NaN                         NaN
# 20              NaN            NaN                         NaN
# 51              NaN            NaN                         NaN
# 72              NaN            NaN                         NaN
# 79              NaN            NaN                         NaN
# 118             NaN            NaN                         NaN
# 124             NaN            NaN                         NaN
# 128             NaN            NaN                         NaN
# 138             NaN            NaN                         NaN
# 140             NaN            NaN                         NaN
# 209             NaN            NaN                         NaN
# 210             NaN            NaN                         NaN
# 211             NaN            NaN                         NaN
# 226             NaN            NaN                         NaN
# 232             NaN            NaN                         NaN
# 245             NaN            NaN                         NaN
# 246             NaN            NaN                         5.0
# 255             NaN            NaN                         NaN
# 278             NaN            NaN                         NaN
# 330             NaN            NaN                         NaN
# 364             NaN            NaN                         NaN
# 381             NaN            NaN                         NaN
# 392             NaN            NaN                         NaN
# 407             NaN            5.0                         NaN
# 431             NaN            NaN                         NaN
# 459             NaN            NaN                         NaN
# 465             NaN            NaN                         NaN
# 474             NaN            NaN                         NaN
# 494             NaN            NaN                         NaN
# 508             NaN            NaN                         NaN
# 521             NaN            NaN                         NaN
# 533             NaN            NaN                         NaN
# 550             NaN            NaN                         NaN
# 566             NaN            NaN                         NaN
# 581             NaN            NaN                         NaN
# 585             5.0            NaN                         NaN
# 595             NaN            NaN                         NaN
# 600             NaN            NaN                         NaN
#
#      Cinema Paradiso (Nuovo cinema Paradiso) (1989)  ...  \
# 14                                              NaN  ...
# 20                                              NaN  ...
# 51                                              NaN  ...
# 72                                              NaN  ...
# 79                                              NaN  ...
# 118                                             NaN  ...
# 124                                             NaN  ...
# 128                                             NaN  ...
# 138                                             NaN  ...
# 140                                             NaN  ...
# 209                                             NaN  ...
# 210                                             NaN  ...
# 211                                             NaN  ...
# 226                                             NaN  ...
# 232                                             NaN  ...
# 245                                             NaN  ...
# 246                                             NaN  ...
# 255                                             NaN  ...
# 278                                             NaN  ...
# 330                                             NaN  ...
# 364                                             NaN  ...
# 381                                             NaN  ...
# 392                                             NaN  ...
# 407                                             NaN  ...
# 431                                             NaN  ...
# 459                                             NaN  ...
# 465                                             NaN  ...
# 474                                             NaN  ...
# 494                                             5.0  ...
# 508                                             NaN  ...
# 521                                             NaN  ...
# 533                                             NaN  ...
# 550                                             NaN  ...
# 566                                             NaN  ...
# 581                                             NaN  ...
# 585                                             NaN  ...
# 595                                             NaN  ...
# 600                                             NaN  ...
#
#      Ocean's Twelve (2004)  Pan's Labyrinth (Laberinto del fauno, El) (2006)  \
# 14                     NaN                                               NaN
# 20                     4.5                                               NaN
# 51                     NaN                                               NaN
# 72                     NaN                                               NaN
# 79                     NaN                                               4.5
# 118                    NaN                                               NaN
# 124                    NaN                                               NaN
# 128                    NaN                                               NaN
# 138                    NaN                                               1.5
# 140                    NaN                                               NaN
# 209                    NaN                                               NaN
# 210                    NaN                                               NaN
# 211                    NaN                                               4.5
# 226                    NaN                                               NaN
# 232                    NaN                                               3.0
# 245                    4.0                                               4.0
# 246                    NaN                                               4.0
# 255                    4.0                                               NaN
# 278                    NaN                                               NaN
# 330                    NaN                                               5.0
# 364                    NaN                                               NaN
# 381                    NaN                                               NaN
# 392                    5.0                                               5.0
# 407                    NaN                                               4.0
# 431                    NaN                                               4.0
# 459                    NaN                                               NaN
# 465                    NaN                                               NaN
# 474                    NaN                                               4.5
# 494                    4.5                                               NaN
# 508                    3.5                                               4.0
# 521                    NaN                                               NaN
# 533                    2.0                                               NaN
# 550                    NaN                                               NaN
# 566                    NaN                                               3.0
# 581                    NaN                                               NaN
# 585                    NaN                                               NaN
# 595                    NaN                                               NaN
# 600                    NaN                                               4.0
#
#      Gattaca (1997)  Starship Troopers (1997)  Django Unchained (2012)  \
# 14              4.5                       NaN                      1.0
# 20              NaN                       NaN                      3.5
# 51              NaN                       NaN                      NaN
# 72              NaN                       NaN                      5.0
# 79              NaN                       3.5                      NaN
# 118             NaN                       NaN                      4.0
# 124             NaN                       NaN                      4.0
# 128             NaN                       5.0                      NaN
# 138             NaN                       NaN                      2.5
# 140             4.0                       NaN                      5.0
# 209             NaN                       NaN                      NaN
# 210             NaN                       NaN                      NaN
# 211             NaN                       NaN                      4.5
# 226             NaN                       NaN                      NaN
# 232             NaN                       NaN                      3.5
# 245             NaN                       NaN                      NaN
# 246             NaN                       NaN                      3.5
# 255             NaN                       NaN                      5.0
# 278             NaN                       3.0                      4.0
# 330             NaN                       4.0                      5.0
# 364             NaN                       NaN                      3.0
# 381             4.5                       NaN                      4.5
# 392             4.0                       NaN                      NaN
# 407             NaN                       NaN                      NaN
# 431             4.0                       NaN                      NaN
# 459             NaN                       NaN                      NaN
# 465             NaN                       NaN                      NaN
# 474             NaN                       4.5                      NaN
# 494             NaN                       3.5                      5.0
# 508             NaN                       NaN                      4.0
# 521             NaN                       NaN                      5.0
# 533             NaN                       4.0                      2.0
# 550             NaN                       NaN                      NaN
# 566             3.0                       NaN                      NaN
# 581             NaN                       NaN                      4.5
# 585             NaN                       NaN                      NaN
# 595             3.5                       NaN                      NaN
# 600             NaN                       NaN                      4.0
#
#      Finding Nemo (2003)  Pulp Fiction (1994)  Mission: Impossible III (2006)  \
# 14                   3.0                  4.0                             NaN
# 20                   NaN                  3.5                             3.5
# 51                   NaN                  NaN                             NaN
# 72                   4.5                  NaN                             NaN
# 79                   NaN                  NaN                             4.5
# 118                  4.0                  4.0                             NaN
# 124                  NaN                  4.5                             NaN
# 128                  NaN                  NaN                             4.0
# 138                  NaN                  NaN                             NaN
# 140                  4.5                  4.0                             NaN
# 209                  NaN                  0.5                             NaN
# 210                  NaN                  4.5                             NaN
# 211                  3.5                  3.5                             NaN
# 226                  4.5                  4.5                             NaN
# 232                  4.0                  4.0                             NaN
# 245                  5.0                  4.0                             NaN
# 246                  4.0                  4.0                             NaN
# 255                  NaN                  NaN                             NaN
# 278                  NaN                  5.0                             NaN
# 330                  4.0                  5.0                             NaN
# 364                  2.5                  NaN                             NaN
# 381                  NaN                  5.0                             NaN
# 392                  NaN                  NaN                             NaN
# 407                  NaN                  NaN                             NaN
# 431                  3.5                  2.5                             3.5
# 459                  5.0                  NaN                             NaN
# 465                  3.5                  NaN                             NaN
# 474                  3.5                  NaN                             NaN
# 494                  NaN                  NaN                             NaN
# 508                  3.5                  3.5                             NaN
# 521                  NaN                  5.0                             NaN
# 533                  4.0                  NaN                             4.0
# 550                  4.0                  3.5                             4.0
# 566                  3.0                  NaN                             NaN
# 581                  NaN                  NaN                             NaN
# 585                  NaN                  NaN                             NaN
# 595                  4.0                  NaN                             NaN
# 600                  5.0                  NaN                             NaN
#
#      Airplane! (1980)  Black Hawk Down (2001)
# 14                NaN                     NaN
# 20                NaN                     NaN
# 51                NaN                     4.0
# 72                NaN                     NaN
# 79                NaN                     NaN
# 118               NaN                     4.0
# 124               NaN                     NaN
# 128               4.0                     4.5
# 138               NaN                     NaN
# 140               NaN                     NaN
# 209               NaN                     NaN
# 210               NaN                     NaN
# 211               4.0                     NaN
# 226               NaN                     NaN
# 232               NaN                     NaN
# 245               3.5                     NaN
# 246               NaN                     NaN
# 255               NaN                     NaN
# 278               3.5                     NaN
# 330               NaN                     NaN
# 364               NaN                     NaN
# 381               NaN                     NaN
# 392               NaN                     NaN
# 407               5.0                     NaN
# 431               NaN                     NaN
# 459               NaN                     NaN
# 465               NaN                     3.5
# 474               NaN                     NaN
# 494               NaN                     NaN
# 508               NaN                     NaN
# 521               NaN                     3.5
# 533               NaN                     NaN
# 550               NaN                     4.0
# 566               NaN                     NaN
# 581               NaN                     NaN
# 585               NaN                     NaN
# 595               3.5                     NaN
# 600               NaN                     NaN
#
# [38 rows x 300 columns]

# %%
# Pick a user ID from the dataset
# Check if user_id exists in cluster index
user_id = 7
if user_id not in cluster.index:
    print(f"User ID {user_id} not found in the cluster.")
    # Handle the case where user_id is not found
    # For example, you could choose a different user_id or exit
else:
    # Get all this user's ratings
    user_ratings = cluster.loc[user_id, :]

    # Which movies did they not rate?
    unrated_movies = user_ratings[user_ratings.isna()].index

    # Get average ratings for unrated movies from the cluster
    # Changed to handle potential NaN values during mean calculation
    avg_ratings = cluster.loc[:, unrated_movies].mean(skipna=True)

    # Sort by rating so the highest rated movies are presented first
    recommended_movies = avg_ratings.sort_values(ascending=False)[:20]

    # Print the recommendations
    print(recommended_movies)
# Out:
# User ID 7 not found in the cluster.

# %% [markdown]
# ## Using Collaborative Filtering (With fast.ai)

# %%
! [ -e /content ] && pip install -Uqq fastai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 64.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 17.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 85.7 MB/s eta 0:00:00

# %%
from fastai.tabular.all import *
from fastai.collab import *

# %% [markdown]
# ### Training a model

# %% [markdown]
# For this, we will use the [Movielens 100k data dataset](https://grouplens.org/datasets/movielens/100k/). We can download it easily and decompress it with the following function:

# %%
path = untar_data(URLs.ML_100k)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='4931584' class='' max='4924029' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.15% [4931584/4924029 00:00&lt;00:00]
#     </div>

# %% [markdown]
# The main table is in `u.data`. Since it's not a proper csv, we have to specify a few things while opening it: the tab delimiter, the columns we want to keep and their names.

# %%
ratings = pd.read_csv(path/'u.data', delimiter='\t', header=None,
                      usecols=(0,1,2), names=['user','movie','rating'])
ratings.head()
# Out:
#    user  movie  rating
# 0   196    242       3
# 1   186    302       3
# 2    22    377       1
# 3   244     51       2
# 4   166    346       1

# %% [markdown]
# Movie ids are not ideal to look at things, so we load the corresponding movie id to the title that is in the table `u.item`:

# %%
movies = pd.read_csv(path/'u.item',  delimiter='|', encoding='latin-1',
                     usecols=(0,1), names=('movie','title'), header=None)
movies.head()
# Out:
#    movie              title
# 0      1   Toy Story (1995)
# 1      2   GoldenEye (1995)
# 2      3  Four Rooms (1995)
# 3      4  Get Shorty (1995)
# 4      5     Copycat (1995)

# %% [markdown]
# Next we merge it to our ratings table:

# %%
ratings = ratings.merge(movies)
ratings.head()
# Out:
#    user  movie  rating                       title
# 0   196    242       3                Kolya (1996)
# 1   186    302       3    L.A. Confidential (1997)
# 2    22    377       1         Heavyweights (1994)
# 3   244     51       2  Legends of the Fall (1994)
# 4   166    346       1         Jackie Brown (1997)

# %% [markdown]
# We can then build a `DataLoaders` object from this table. By default, it takes the first column for user, the second column for the item (here our movies) and the third column for the ratings. We need to change the value of `item_name` in our case, to use the titles instead of the ids:

# %%
dls = CollabDataLoaders.from_df(ratings, item_name='title', bs=64)

# %% [markdown]
# In all applications, when the data has been assembled in a `DataLoaders`, you can have a look at it with the `show_batch` method:

# %%
dls.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>user</th>
#       <th>title</th>
#       <th>rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>577</td>
#       <td>Aladdin (1992)</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>305</td>
#       <td>Apt Pupil (1998)</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>387</td>
#       <td>12 Angry Men (1957)</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536</td>
#       <td>Sound of Music, The (1965)</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>917</td>
#       <td>Mission: Impossible (1996)</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>28</td>
#       <td>Aladdin (1992)</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>269</td>
#       <td>Aliens (1986)</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>823</td>
#       <td>GoodFellas (1990)</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>13</td>
#       <td>Milk Money (1994)</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>345</td>
#       <td>Titanic (1997)</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# fastai can create and train a collaborative filtering model by using `collab_learner`:

# %%
learn = collab_learner(dls, n_factors=50, y_range=(0, 5.5))

# %% [markdown]
# It uses a simple dot product model with 50 latent factors. To train it using the 1cycle policy, we just run this command:

# %%
learn.fit_one_cycle(5, 5e-3, wd=0.1)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.899799</td>
#       <td>0.942900</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.675498</td>
#       <td>0.888756</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.511819</td>
#       <td>0.865963</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.463549</td>
#       <td>0.852208</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.433222</td>
#       <td>0.846726</td>
#       <td>00:07</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Here's [some benchmarks](https://www.librec.net/release/v1.3/example.html) on the same dataset for the popular Librec system for collaborative filtering. They show best results based on RMSE of 0.91 (scroll down to the 100k dataset), which corresponds to an MSE of `0.91**2 = 0.83`. So in less than a minute, we got pretty good results!

# %% [markdown]
# ### Interpretation

# %% [markdown]
# Let's analyze the results of our previous model. We will keep the 1000 most rated movies for this:

# %%
g = ratings.groupby('title')['rating'].count()
top_movies = g.sort_values(ascending=False).index.values[:1000]
top_movies[:10]
# Out:
# array(['Star Wars (1977)', 'Contact (1997)', 'Fargo (1996)',
#        'Return of the Jedi (1983)', 'Liar Liar (1997)',
#        'English Patient, The (1996)', 'Scream (1996)', 'Toy Story (1995)',
#        'Air Force One (1997)', 'Independence Day (ID4) (1996)'],
#       dtype=object)

# %% [markdown]
# ### Movie bias

# %% [markdown]
# Our model has learned one bias per movie, a unique number independent of users that can be interpreted as the intrinsic "value" of the movie. We can grab the bias of each movie in our `top_movies` list with the following command:

# %%
movie_bias = learn.model.bias(top_movies, is_item=True)
movie_bias.shape
# Out:
# torch.Size([1000])

# %% [markdown]
# Let's compare those biases with the average ratings:

# %%
mean_ratings = ratings.groupby('title')['rating'].mean()
movie_ratings = [(b, i, mean_ratings.loc[i]) for i,b in zip(top_movies,movie_bias)]

# %% [markdown]
# Now let's have a look at the movies with the worst bias:

# %%
item0 = lambda o:o[0]
sorted(movie_ratings, key=item0)[:15]
# Out:
# [(tensor(-0.3515),
#   'Lawnmower Man 2: Beyond Cyberspace (1996)',
#   1.7142857142857142),
#  (tensor(-0.3324), 'Kansas City (1996)', 2.260869565217391),
#  (tensor(-0.3233), 'Crow: City of Angels, The (1996)', 1.9487179487179487),
#  (tensor(-0.3192), 'Mortal Kombat: Annihilation (1997)', 1.9534883720930232),
#  (tensor(-0.3177),
#   'Children of the Corn: The Gathering (1996)',
#   1.3157894736842106),
#  (tensor(-0.2798), 'Cable Guy, The (1996)', 2.339622641509434),
#  (tensor(-0.2640), 'Hellraiser: Bloodline (1996)', 2.0),
#  (tensor(-0.2574), "Joe's Apartment (1996)", 2.2444444444444445),
#  (tensor(-0.2511), 'Keys to Tulsa (1997)', 2.24),
#  (tensor(-0.2500), 'Bio-Dome (1996)', 1.903225806451613),
#  (tensor(-0.2346), 'Free Willy 3: The Rescue (1997)', 1.7407407407407407),
#  (tensor(-0.2241), 'Halloween: The Curse of Michael Myers (1995)', 2.2),
#  (tensor(-0.2205), 'Barb Wire (1996)', 1.9333333333333333),
#  (tensor(-0.2165), 'Leave It to Beaver (1997)', 1.8409090909090908),
#  (tensor(-0.2142), 'Spice World (1997)', 2.1153846153846154)]

# %% [markdown]
# Or the ones with the best bias:

# %%
sorted(movie_ratings, key=lambda o: o[0], reverse=True)[:15]
# Out:
# [(tensor(0.6062), 'Titanic (1997)', 4.2457142857142856),
#  (tensor(0.5605), "Schindler's List (1993)", 4.466442953020135),
#  (tensor(0.5415), 'Silence of the Lambs, The (1991)', 4.28974358974359),
#  (tensor(0.5369), 'As Good As It Gets (1997)', 4.196428571428571),
#  (tensor(0.5318), 'Close Shave, A (1995)', 4.491071428571429),
#  (tensor(0.5253), 'L.A. Confidential (1997)', 4.161616161616162),
#  (tensor(0.5066), 'Apt Pupil (1998)', 4.1),
#  (tensor(0.5007), 'Good Will Hunting (1997)', 4.262626262626263),
#  (tensor(0.4985), 'Casablanca (1942)', 4.45679012345679),
#  (tensor(0.4886), 'Rear Window (1954)', 4.3875598086124405),
#  (tensor(0.4796), 'Shawshank Redemption, The (1994)', 4.445229681978798),
#  (tensor(0.4717), 'Star Wars (1977)', 4.3584905660377355),
#  (tensor(0.4667), 'To Kill a Mockingbird (1962)', 4.292237442922374),
#  (tensor(0.4587), "One Flew Over the Cuckoo's Nest (1975)", 4.291666666666667),
#  (tensor(0.4568), 'North by Northwest (1959)', 4.284916201117318)]

# %% [markdown]
# There is certainly a strong correlation!

# %% [markdown]
# ### Movie weights

# %% [markdown]
# Now let's try to analyze the latent factors our model has learned. We can grab the weights for each movie in `top_movies` the same way as we did for the bias before.

# %%
movie_w = learn.model.weight(top_movies, is_item=True)
movie_w.shape
# Out:
# torch.Size([1000, 50])

# %% [markdown]
# Let's try a PCA to reduce the dimensions and see if we can see what the model learned:

# %%
movie_pca = movie_w.pca(3)
movie_pca.shape
# Out:
# torch.Size([1000, 3])

# %%
fac0,fac1,fac2 = movie_pca.t()
movie_comp = [(f, i) for f,i in zip(fac0, top_movies)]

# %% [markdown]
# Here are the highest score on the first dimension:

# %%
sorted(movie_comp, key=itemgetter(0), reverse=True)[:10]
# Out:
# [(tensor(1.1380), 'Godfather, The (1972)'),
#  (tensor(1.0882),
#   'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)'),
#  (tensor(1.0436), 'Persuasion (1995)'),
#  (tensor(1.0413), 'Secrets & Lies (1996)'),
#  (tensor(0.9675), 'Casablanca (1942)'),
#  (tensor(0.9598), 'Usual Suspects, The (1995)'),
#  (tensor(0.9484), 'Lawrence of Arabia (1962)'),
#  (tensor(0.9439), 'Boot, Das (1981)'),
#  (tensor(0.9427), 'Some Folks Call It a Sling Blade (1993)'),
#  (tensor(0.9304), "Schindler's List (1993)")]

# %% [markdown]
# And the worst:

# %%
sorted(movie_comp, key=itemgetter(0))[:10]
# Out:
# [(tensor(-1.2210), 'Home Alone 3 (1997)'),
#  (tensor(-1.1514), 'Jungle2Jungle (1997)'),
#  (tensor(-1.1392), 'Children of the Corn: The Gathering (1996)'),
#  (tensor(-1.0818), 'Free Willy 3: The Rescue (1997)'),
#  (tensor(-1.0759), 'Leave It to Beaver (1997)'),
#  (tensor(-1.0606), 'Super Mario Bros. (1993)'),
#  (tensor(-1.0605), 'Congo (1995)'),
#  (tensor(-1.0532), "McHale's Navy (1997)"),
#  (tensor(-1.0530), 'Flipper (1996)'),
#  (tensor(-1.0420), 'Jaws 3-D (1983)')]

# %% [markdown]
# Same thing for our second dimension:

# %%
movie_comp = [(f, i) for f,i in zip(fac1, top_movies)]

# %%
sorted(movie_comp, key=itemgetter(0), reverse=True)[:10]
# Out:
# [(tensor(1.1282), 'Braveheart (1995)'),
#  (tensor(1.1263), 'Titanic (1997)'),
#  (tensor(1.0801), 'Forrest Gump (1994)'),
#  (tensor(0.9445), 'Ghost (1990)'),
#  (tensor(0.9197), 'Raiders of the Lost Ark (1981)'),
#  (tensor(0.9078), 'Independence Day (ID4) (1996)'),
#  (tensor(0.8940), 'American President, The (1995)'),
#  (tensor(0.8532), "Mr. Holland's Opus (1995)"),
#  (tensor(0.8224), 'Field of Dreams (1989)'),
#  (tensor(0.8093), 'Top Gun (1986)')]

# %%
sorted(movie_comp, key=itemgetter(0))[:10]
# Out:
# [(tensor(-0.8553), 'Brazil (1985)'),
#  (tensor(-0.8504), 'Serial Mom (1994)'),
#  (tensor(-0.7985), 'Trainspotting (1996)'),
#  (tensor(-0.7782), 'Lost Highway (1997)'),
#  (tensor(-0.7511), 'Spanking the Monkey (1994)'),
#  (tensor(-0.7482), 'Road to Wellville, The (1994)'),
#  (tensor(-0.7473), 'Money Talks (1997)'),
#  (tensor(-0.7294), 'Three Colors: Blue (1993)'),
#  (tensor(-0.7171), 'Clockwork Orange, A (1971)'),
#  (tensor(-0.7040), 'Very Brady Sequel, A (1996)')]

# %% [markdown]
# And we can even plot the movies according to their scores on those dimensions:

# %%
idxs = np.random.choice(len(top_movies), 50, replace=False)
idxs = list(range(50))
X = fac0[idxs]
Y = fac2[idxs]
plt.figure(figsize=(15,15))
plt.scatter(X, Y)
for i, x, y in zip(top_movies[idxs], X, Y):
    plt.text(x,y,i, color=np.random.rand(3)*0.7, fontsize=11)
plt.show()

# %% [markdown]
# # Exercise 2
#
# ## Play around with different collaborative filtering model parameters such as n_factors and other parameters.
# ## Identify if any such parameters have impact on the speed of convergence or the performance on the model

# %%
# !pip install scikit-surprise
# Out:
# Collecting scikit-surprise
#   Downloading scikit_surprise-1.1.4.tar.gz (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.4/154.4 kB 5.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-surprise) (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-surprise) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-surprise) (1.13.1)
# Building wheels for collected packages: scikit-surprise
#   Building wheel for scikit-surprise (pyproject.toml) ... done
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.4-cp311-cp311-linux_x86_64.whl size=2505170 sha256=b0b984353e20a25d07dbce142d9aa28f9f2cfe6dd489d55e1ca9bca9e7ff5571
#   Stored in directory: /root/.cache/pip/wheels/2a/8f/6e/7e2899163e2d85d8266daab4aa1cdabec7a6c56f83c015b5af
# Successfully built scikit-surprise
# Installing collected packages: scikit-surprise
# Successfully installed scikit-surprise-1.1.4

# %%
import numpy as np
import pandas as pd
from surprise import SVD, Dataset, Reader
from surprise.model_selection import cross_validate

# Generate a larger synthetic dataset (50 ratings)
np.random.seed(42)
num_users = 10
num_items = 10
ratings_dict = {
    "userID": np.random.randint(1, num_users + 1, 50),
    "itemID": np.random.randint(101, 101 + num_items, 50),
    "rating": np.random.randint(1, 6, 50)  # Ratings from 1 to 5
}
df = pd.DataFrame(ratings_dict)

# Define rating scale
reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(df[['userID', 'itemID', 'rating']], reader)

# Experiment with different parameters
params = [
    {"n_factors": 20, "lr_all": 0.005, "reg_all": 0.02},  # Default
    {"n_factors": 50, "lr_all": 0.01, "reg_all": 0.05},  # Higher complexity
    {"n_factors": 10, "lr_all": 0.001, "reg_all": 0.1},  # Simpler model
]

# Train and evaluate models
for param in params:
    algo = SVD(n_factors=param["n_factors"], lr_all=param["lr_all"], reg_all=param["reg_all"])
    results = cross_validate(algo, data, cv=3, verbose=False)  # Set verbose=False for cleaner output
    mean_rmse = np.mean(results['test_rmse'])
    mean_mae = np.mean(results['test_mae'])

    print(f"Params: {param}")
    print(f"Mean RMSE: {mean_rmse:.4f}, Mean MAE: {mean_mae:.4f}\n")
# Out:
# Params: {'n_factors': 20, 'lr_all': 0.005, 'reg_all': 0.02}
# Mean RMSE: 1.3632, Mean MAE: 1.1665
#
# Params: {'n_factors': 50, 'lr_all': 0.01, 'reg_all': 0.05}
# Mean RMSE: 1.3949, Mean MAE: 1.1774
#
# Params: {'n_factors': 10, 'lr_all': 0.001, 'reg_all': 0.1}
# Mean RMSE: 1.3467, Mean MAE: 1.1584
